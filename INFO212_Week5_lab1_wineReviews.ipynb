# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Week5_lab1_wineReviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Lab 1: Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Exercise:
# Download the data file "winemag-data-130k-v2.csv" and load it into a Pandas DataFrame using the column 0 as index. This data set contains 130k reviews for different wine verieties. Answer the following questions:

# %% [markdown]
# 1. What countries are in the review dataset? List all unique country names.

# %% [markdown]
# 2. What is the value of the 'description' column for the third review?

# %% [markdown]
# 3. Select the country, province, region_1, and region_2 columns of the records at the 0, 1, 10, and 100 index positions.

# %% [markdown]
# 4. Select all the reviews for wines made in 'Italy'. How many reviews are there for wines made in 'Italy'?

# %% [markdown]
# 5. Suppose the 'points' column represents the rating of a wine. An above-averagely good wine has a value in 'points' equal or greater than 90. Between France and Italy, which country has more reviews for its above-averagely good wines?

# %% [markdown]
# 6. What are the top-10 countries with the most wine reviews?

# %% [markdown]
# 7. What is the median of the price?

# %% [markdown]
# 8. Create a new column 'price_norm' by subtracting the median price from the price column. Use the DataFrame.apply method.

# %% [markdown]
# 9. Create a new column 'bargain' which contains the points-to-price ratio. Which wine(s) is/are the "best bargain", e.g., which wine(s) has/have the highest points-to-price ratio in the dataset?
