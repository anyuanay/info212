# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Week7_Lab2_Aggregation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Week 7: Lab 2: Aggregation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. Download the nba-2016.csv dataset. Create a DataFrame df from the dataset. Show information of the DataFrame.

# %% [markdown]
# 2. Group by the Visitor/Neutral teams. Compute the aveage points (PTS) for each team playing as visiting team.

# %% [markdown]
# 3. Add a new column 'VisitorWon' which has True for the Visiting team won and False otherwise.

# %% [markdown]
# 4. Compute the rate of VisitorWon for each team playing away during the 2016 season, in descending order. Which team was most likely to win as a visiting team? Which team was least likely to win as a visiting team? What was the winning rate of the 76ers as a visiting team in 2016 season?

# %% [markdown]
# 5. (optional question) Define a function 'top' that returns the top two rows based on a given col value. List each team's top 2 winning visiting games in which the team got top 2 highest points. Order the results by team names. Which two games did the 76ers score the most and win as a visiting team?
