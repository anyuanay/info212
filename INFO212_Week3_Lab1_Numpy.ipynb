# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Week3_Lab1_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Week 3: Lab 1: Numpy

# %% [markdown]
# ## What to do:
# - Answer each question individually.
# - Comment on each single statement.
# - Each missing comment will be penalized by 1 point.
# - Verify the code by showing meaningful results.

# %%
import numpy as np

# %% [markdown]
# ## Exercise 1:
# When you add a (3x5) numpy array to a (1x5) numpy array, array broadcast works.  Explain **in your own words** which array is broadcasted on which dimension, with indicating the dimension number.

# %% [markdown]
# ## Exercise 2:
# Create a CSV file containing 30 numbers in your Google Drive or the virtual disk. Load the CSV file as a numpy array in 5 rows and 6 columns. Using numpy operation to show:
# - means of rows
# - means of columns
# - the overall mean
# - A subset of the array. Show the content and shape of the subset.
