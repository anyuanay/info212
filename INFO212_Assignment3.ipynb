# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style="text-align:center"> Drexel University </h1>
# <h2 style = "text-align:center"> College of Computing and Informatics</h2>
# <h2 style = "text-align:center">INFO 212: Data Science Programming I</h2>
# <h3 style = "text-align:center">Assignment 3</h3>
# <div style="text-align:center; border-style:solid; padding: 10px">
# <div style="font-weight:bold">Due Date: Sunday, May 15, 2022</div>
# This assignment counts for 15% of the final grade
# </div>
#
# <h3 style="color:red; font-weight:bold; text-decoration: underline">DON'T FORGET TO PUT YOUR NAME BELOW</h3>
#
# ### STUDENT NAME:
#
#
# ### A. Assignment Overview
# This assignment provides the opportunity for you to practice with the capabilities of handling with external data in Python.
#
# ### B. What to Hand In
#
# Sumbit a completed this Jupyter notebook.
#
# ### C. How to Hand In
#
# Submit your Jupyter notebook file through the course website in the Blackboard Learn system.
#
# ### D. When to Hand In
#
# 1. Submit your assignment no later than 11:59pm in the due date.
# 2. There will be a 10% (absolute value) deduction for each day of lateness, to a maximum of 3 days; assignments will not be accepted beyond that point. Missing work will earn a zero grade.
#
# ### E. Written Presentation Requirements (if applicable)
# Images must be clear and legible. Assignments will be judged on the basis of visual appearance, grammatical correctness, and quality of writing, as well as their contents. Please make sure that the text of your assignments is well-structured, using paragraphs, full sentences, and other features of well-written presentation. Text font size should be either 11 or 12 points.
#
# ### F. Marking Schemes:
# Marking assignments will be based on several aspects: presentation, correctness and coding styles.
#
# The following is a set of guidelines for the presentation and coding style in this course:
# - 1. Write good comments. Marks will be deducted if there are no comments.
# - 2. Your comments must mention the purpose of each parameter, and must be grammatically correct.
# - 3. When breaking up a long line, break it before an operator, not after.
# - 4. Present your code and answers in well-structured format. First, copy the quesiton; second, write your code and show the intermediate analysis results; in the end, answer the question using the analysis results.
#
# ### G. Data Sets
#
# This assignment needs the data sets specified in the questions.
#
# ### H. Answer the following questions

# %% [markdown]
# #### Question 1 [30 Marks]:
#
# Wikipedia has a Webpage: [List of countries by past and future population](https://en.wikipedia.org/wiki/List_of_countries_by_past_and_future_population). On this page, there are three tables containing the estimated populations from 1950 to 2050 for all the countries. Read the description on the Webpage to understand the information in the tables. Download the Webpage as an HTML file in your disk. Read in the tables using Pandas' `read_html` method. Write code to answer the following questions.
# 1. How many tables have you read in?
# 2. What are the first 5 rows of the DataFrame correpsonding to the table "Estimates between the years 1950 and 1980 (in thousands)"?
# 3. How many countries does the Wikipedia page list their populations?
# 4. Create a DataFrame containing all the data from the population tables. i.e., the DataFrame contains the popultation and average annual growth data from 1950-2050. You need to combine the three population tables. How many rows and columns in the final combined DataFrame?
# 5. For the top 10 most populous countries at 1950, how have their populations changed and will change since then? Plot their population data from 1950-2050 (in 5-year interval). The plot should use years 1950-2050 as x axis, and population numbers as y axis. The following figure shows the expected result.
# ![](https://i.imgur.com/6W9RuZO.png)
# 6. For the same top 10 most populous contries at 1950, how have their average annual growths changed and will change since then? Plot the average annual growth for each previous five-year period starting from 1955 to 2050 in 5-year interval. The following figure shows the expected result.
# ![](https://i.imgur.com/ImXjIo0.png)

# %% [markdown]
# #### Question 2 [30 marks]:
# The file `nobelprize-laureate.json` is a JSON file containing the information about Nobel Prize laureates. Create a Pandas DataFrame from the JSON file. Complete the following steps and answer the questions:
# 1. Write statements to answer the question: How many unique countries are listed in this dataset as the Nobel Prize laureates's birth countries?
# 2. Which are the top-20 birth countries of the laureats? Plot the top-20 birth countries in a bar chart showing the country names and the number of laureats born in the countries.
# 3. Since 1901 up to the latest year available in the dataset, does the number of laureates' birth countries has changed significiantly? Starting from 1901 to the latest year in the dataset, extract the birth countries of the laureates at each year. Plot a bar chart showing the number of unique birth countries of the laureates over the years.
# ![](https://i.imgur.com/Em0Qv7i.png)

# %% [markdown]
# #### Question 3 [40 marks]:
#
# The file `weather-samples.csv` contains weather data measured at a weather station for a period of three years. Sensors at the weather station capture weather-related measurements such as air temperature, air pressure, and relative humidity. Load  the data to a pandas DataFrame. Write code to answer the following questions:
# 1. How many records does the data contain?
# 2. How many rows contain missing values?
# 3. How many columns contain missing values?
# 4. List the numbers of missing values for all columns.
# 5. List the mean values of all columns.
# 6. For each missing value, fill up it with the mean value of the column where the missing value is located in.
# 7. Show there is no missing value after filling up.
# 8. List the mean values of all columns after filling up. Does any mean value change?
# 9. Plot the histogram of the value `relative_humidity_3pm`.
# 10. A weather forecast problem is to predict a measure in a future time using the measurements at earlier moments. For example, the dataset contains several measurements at 9am and one measurement `relative_humidity_3pm` at 3pm. It is interesting to know whether we can predict `relative_humidity_3pm` using the values at 9am. This is a typical supervised machine learning problem. Using plots to visualize the relationships between the measurements at 9am and `relative_humidity_3pm`. What do you find? Discuss the impacts of the measurements at 9am to the values of `relaive_humidity_3pm`.
