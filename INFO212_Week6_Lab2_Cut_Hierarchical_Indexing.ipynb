# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Week6_Lab2_Cut_Hierarchical_Indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Lab: Cut and Hierarchical Indexing

# %% [markdown]
# 1. Download and upload the csv file "Cleaned_Laptop_data.csv" Read the data as a Pandas DataFrame. Show some informaiton and summary statistics using shape, columns, head(), info(), describe().

# %% [markdown]
# 2. Plot the histogram of latest_price. Use pd.cut() to categorize the latest_price into 3 categories: cheap in the range [0, 25000), regular in the range [25000, 100000), and expensive in the range 100000+. Show the distribution of the price categories in a bar plot.

# %% [markdown]
# 3. Extract 'brand', 'model', 'latest_price', and 'ratings' to a new DataFrame df1

# %% [markdown]
# 4. For df1, set 'brand' and 'model' as hierarchical index and assign the result to df2; show df2 and its index. Explain why the same brand was not grouped together, for example 'ASUS'.

# %% [markdown]
# 5. Using df2, extract the model, latest_price, ratings of all APPLE laptops. Reset the index of the resultant DataFrame so that model becomes a column.

# %% [markdown]
# 6. Using df2, extract the latest_prices of APPLE MacBook.

# %% [markdown]
# 7. Using df2, extract the latest_prices of all model 'Core' of any brands (practice with the df.xs() function.)
