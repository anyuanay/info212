# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Week6_Lab1_Plot_museum_daily_temperatures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Lab 1: Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# 1: Read the LA Museum Visitors data file into a DataFrame. Create a line chart that shows how the number of visitors to each museum evolved over time. Your figure should have multiple lines (one for each museum).

# %% [markdown]
# 2: Create a line chart that shows how the number of visitors to Avila Adobe has evolved over time.

# %% [markdown]
# 3: Does Avila Adobe get more visitors:
# - in September-February (in LA, the fall and winter months), or
# - in March-August (in LA, the spring and summer)?
#
# Using this information, when should the museum staff add additional seasonal employees?

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# 1: Load the `daily-minimum-temperatures-in-me.csv` as a DataFrame. Create a line plot showing the changes of the temperatures over the time. Label the xticks with quarterly months such as `1981-01`, `1981-04`, `1981-07`, `1981-10`, `1982-01`,...`1990-01`, `1990-04`,...

# %% [markdown]
# 2: Discuss the temperature patterns during a period of year. Which geographical location could have these temperature measurements?
