# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Week4_Lab2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Week 4: Lab 2: Pandas

# %% [markdown]
# ## What to do:
# - Answer each question individually.
# - Comment on each single statement.
# - Each missing comment will be penalized by 1 point.
# - Verify the code by showing meaningful results.

# %% [markdown]
# Download and upload the file 'housing.csv'
# ```
# from google.colab import files
# files.upload()
# ```

# %% [markdown]
# import packages

# %% [markdown]
# ## Exercise 1:
#
# Read in the housing.csv as a Pandas DataFrame using ```pd.read_csv()```. Show the head, shape, and columns of the data frame.

# %% [markdown]
# ## Exercise 2:
# Compute summary statistics of the data.

# %% [markdown]
# ## Exercise 3:
#
# Practice with various indexing, selection and filtering on the data frame. For example, extract the last 50 records and their housing_median_age and median_house_value.

# %% [markdown]
# ## Exercise 4:
#
# How many types of ocean proximity?

# %% [markdown]
# ## Exercise 5:
#
# What is the distribution of different types of ocean proximity?

# %% [markdown]
# ## Discussion:
# Write a brief discussion of your insights about the data in 100 words or less.
