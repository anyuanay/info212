# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Week1_2_Lab_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Week 1-Lab 2: Python

# %% [markdown]
# ## Exercise 1:
#
# Write a for loop to print out every pair of two consecutive letters (bi-grams) in the string "Hello World".

# %% [markdown]
# ## Exercise 2:
#
# Write a function to check whether two strings are anagrams, for example, "New York Times" = anagram("monkeys write").

# %% [markdown]
# ## Exercise 3:
#
# Given a string s = "This sentence is false". Extract the sub-substring "sentence is". Print out the individual characters each on a line.
