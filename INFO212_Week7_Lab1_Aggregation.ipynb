# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/info212/blob/main/INFO212_Week7_Lab1_Aggregation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Week 7: Lab 1: Aggregation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. Download and upload the train.csv. Create a DataFrame df from the data set. Show information of the DataFrame.

# %% [markdown]
# 2. The Survived column has binary values 1 and 0. Compute the average Survived rate grouped by Pclass in ascending order.

# %% [markdown]
# 3. The Survived column has binary values 1 and 0. Compute the average Survived rate grouped by Pclass and Cabin. Show the results in Survived rate ascending order within each Pclass group.

# %% [markdown]
# 4. Create a new column 'Age_cats` using the Pandas cut() function to categorizes Ages into Young, Middle_aged, and Senior category. Compute the Survived rate for each age group in descending order.

# %% [markdown]
# 5 (optional question). (Map the Embarked cities as 'S' to 'Southampton', 'C' to 'Cherbourg', 'Q' to 'Queenstown'. Compute the Survived rate by each embarked city using the mapping.)
